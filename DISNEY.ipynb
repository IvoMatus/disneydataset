# %% [markdown]
# ## Librerías

# %%
from bs4 import BeautifulSoup as bs
from bs4 import NavigableString, Tag
import requests

# %%
#Cargar la página
r = requests.get("https://es.wikipedia.org/wiki/Toy_Story_3")

#Convertir a objeto bs4
soup = bs(r.content)
#imprimir

contents = soup.prettify()
print(contents)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Toy Story 3 - Wikipedia, la enciclopedia libre
#   </title>
#   <script>
# ...

# %%
#obtener la info necesaria
info_box = soup.find(class_="infobox plainlist plainlinks")
#print(info_box.prettify())
info_rows = info_box.find_all("tr")
for row in info_rows:
    print(row.prettify())
# Out:
# <tr>
#  <th class="cabecera cine" colspan="3" style="text-align:center;background-color:transparent;color:black;background-color:#ABD2D0; font-style:italic;">
#   <i>
#    Toy Story 3
#   </i>
#  </th>
# </tr>
#
# <tr>
#  <td colspan="3" style="text-align:center;">
#   <a class="image" href="/wiki/Archivo:Toy_Stoy_3_logo.svg">
#    <img alt="Toy Story 3 logo.svg" data-file-height="338" data-file-width="300" decoding="async" height="248" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Toy_Stoy_3_logo.svg/220px-Toy_Stoy_3_logo.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Toy_Stoy_3_logo.svg/330px-Toy_Stoy_3_logo.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Toy_Stoy_3_logo.svg/440px-Toy_Stoy_3_logo.svg.png 2x" width="220"/>
#   </a>
#  </td>
# </tr>
#
# <tr>
#  <th colspan="3" style="text-align:center;background-color:#ABD2D0;">
#   Ficha técnica
#  </th>
# </tr>
#
# <tr>
#  <th scope="row" style="text-align:left;">
# ...

# %%
movie_info = {}

for index, row in enumerate(info_rows):
    if index == 0:
        movie_info['Titulo'] = row.find("th").get_text()
    elif index == 1 or index == 2 or index == 13 or index == 22:
        continue # porque es la foto de la película o cabecera
    elif (2 < index < 12) or (13 < index < 16) or (22 < index < 27):
        content_key = row.find("th").get_text()
        content_value = row.find("td").get_text().replace("\n"," ").replace('200b','')
        movie_info[content_key] = content_value

movie_info
# Out:
# {'Titulo': 'Toy Story 3',
#  'Dirección': ' Lee Unkrich',
#  'Producción': ' Darla K. Anderson John Lasseter (producción ejecutiva)',
#  'Diseño de producción': ' Bob Pauley',
#  'Guion': ' Michael Arndt',
#  'Historia': ' John LasseterAndrew StantonLee Unkrich',
#  'Música': ' Randy Newman',
#  'Fotografía': ' Jeremy LaskyKim White',
#  'Montaje': ' Ken Schretzmann',
#  'Protagonistas': ' Tom HanksTim AllenJoan CusackDon RicklesWhoopi GoldbergBonnie HuntMichael KeatonTiffany Robinson[1]\u200b',
#  'País': ' Estados Unidos',
#  'Año': ' 2010',
#  'Distribución': ' Walt Disney Studios Motion Pictures',
#  'Estudio': ' The Walt Disney Company',
#  'Presupuesto': ' $200 000 000[2]\u200b',
#  'Recaudación': ' $1 066 969 703[2]\u200b'}

# %%
movie_info = {}
def get_content_value(row_data): # hay casos en que hay break lines entonces:
    if row_data.find("br"):
        return [br.get_text().par for br in row_data.find_all("br")]
    else: # si la fila no tiene lista entonces vale pico
        return row_data.get_text().replace("\n","")

# %%
for index, row in enumerate(info_rows):
    if index == 0:
        movie_info['Titulo'] = row.find("th").get_text()
    elif index == 1 or index == 2 or index == 13 or index == 22:
        continue # porque es la foto de la película o cabeceras de tabla zZz
    elif (3 < index < 12) or (13 < index < 16) or (23 < index < 27):
        content_key = row.find("th").get_text()
        content_value = get_content_value(row.find("td colspan"))
        movie_info[content_key] = content_value
movie_info
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-50c70a9ca967> in <module>
#       6     elif (3 < index < 12) or (13 < index < 16) or (23 < index < 27):
#       7         content_key = row.find("th").get_text()
# ----> 8         content_value = get_content_value(row.find("td colspan"))
#       9         movie_info[content_key] = content_value
#      10 movie_info
#
# <ipython-input-68-b79fec9b0e57> in get_content_value(row_data)
#       1 movie_info = {}
#       2 def get_content_value(row_data): # hay casos en que hay break lines entonces:
# ----> 3     if row_data.find("br"):
#       4         return [br.previous_sibling for br in row_data.find_all("br")]
#       5     else: # si la fila no tiene lista entonces vale pico
#
# AttributeError: 'NoneType' object has no attribute 'find'
